# %%
import pandas as pd
from pathlib import Path
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
res = 'run_v1/csv_results/'

# %%
df = pd.read_parquet(res + 'all.parquet')

# %%
df
# Out:
#     value  distance  amount      s_exp                     source
# 0   100.0    1905.6   34.80  78.500940  route_26_evening_shortest
# 1    98.0     583.6   10.66  78.500940  route_26_evening_shortest
# 2    99.0     412.5    7.53  78.500940  route_26_evening_shortest
# 3    10.0     316.1    5.77  78.500940  route_26_evening_shortest
# 4    78.0     280.8    5.13  78.500940  route_26_evening_shortest
# ..    ...       ...     ...        ...                        ...
# 12   89.0      48.2    0.64  28.051924   route_9_noon_recommended
# 13   95.0      23.6    0.31  28.051924   route_9_noon_recommended
# 14   70.0      20.3    0.27  28.051924   route_9_noon_recommended
# 15   34.0      11.8    0.16  28.051924   route_9_noon_recommended
# 16   91.0       5.0    0.07  28.051924   route_9_noon_recommended
#
# [8082 rows x 5 columns]

# %%
df['route_id'] = df['source'].str.split('_').str[1]
df['route_id'] = df['source'].str.split('_').str[1]
df['time_day'] = df['source'].str.split('_').str[2]
df['type'] = df['source'].str.split('_').str[3]
df
# Out:
#     value  distance  amount      s_exp                     source route_id  \
# 0   100.0    1905.6   34.80  78.500940  route_26_evening_shortest       26
# 1    98.0     583.6   10.66  78.500940  route_26_evening_shortest       26
# 2    99.0     412.5    7.53  78.500940  route_26_evening_shortest       26
# 3    10.0     316.1    5.77  78.500940  route_26_evening_shortest       26
# 4    78.0     280.8    5.13  78.500940  route_26_evening_shortest       26
# ..    ...       ...     ...        ...                        ...      ...
# 12   89.0      48.2    0.64  28.051924   route_9_noon_recommended        9
# 13   95.0      23.6    0.31  28.051924   route_9_noon_recommended        9
# 14   70.0      20.3    0.27  28.051924   route_9_noon_recommended        9
# 15   34.0      11.8    0.16  28.051924   route_9_noon_recommended        9
# 16   91.0       5.0    0.07  28.051924   route_9_noon_recommended        9
#
#    time_day         type
# 0   evening     shortest
# 1   evening     shortest
# 2   evening     shortest
# 3   evening     shortest
# 4   evening     shortest
# ..      ...          ...
# 12     noon  recommended
# 13     noon  recommended
# 14     noon  recommended
# 15     noon  recommended
# 16     noon  recommended
#
# [8082 rows x 8 columns]

# %%
dfw = df.groupby('source')['distance'].sum()

dfw = dfw.to_frame().reset_index()

# %%
df_exp = df[['source', 's_exp', 'time_day']]
df_exp = df_exp.drop_duplicates()

# %%
df_exp
# Out:
#                           source       s_exp   time_day
# 0      route_26_evening_shortest   78.500940    evening
# 0      route_11_evening_shortest   34.643414    evening
# 0    route_11_afternoon_shortest   47.935622  afternoon
# 0   route_15_evening_recommended    7.175314    evening
# 0    route_24_afternoon_shortest  100.000000  afternoon
# ..                           ...         ...        ...
# 0    route_5_morning_recommended   22.551715    morning
# 0         route_18_noon_shortest    2.624317       noon
# 0      route_13_noon_recommended   32.707801       noon
# 0      route_24_noon_recommended   99.985131       noon
# 0       route_9_noon_recommended   28.051924       noon
#
# [320 rows x 3 columns]

# %%
df_merged = dfw.merge(df_exp[['source', 's_exp', 'time_day']], on='source', how='inner')

df_merged['route_type'] = df_merged['source'].str.split('_').str[3]

df_merged
# Out:
#                             source  distance      s_exp   time_day  \
# 0    route_0_afternoon_recommended    9428.4  42.863169  afternoon
# 1       route_0_afternoon_shortest    8968.3  43.237247  afternoon
# 2      route_0_evening_recommended    9509.0  31.369408    evening
# 3         route_0_evening_shortest    9004.7  34.267982    evening
# 4      route_0_morning_recommended    9355.5  37.661867    morning
# ..                             ...       ...        ...        ...
# 315       route_9_evening_shortest    7490.4  17.154037    evening
# 316    route_9_morning_recommended    8576.0   9.043925    morning
# 317       route_9_morning_shortest    8506.3   8.894114    morning
# 318       route_9_noon_recommended    7553.3  28.051924       noon
# 319          route_9_noon_shortest    7490.4  28.287488       noon
#
#       route_type
# 0    recommended
# 1       shortest
# 2    recommended
# 3       shortest
# 4    recommended
# ..           ...
# 315     shortest
# 316  recommended
# 317     shortest
# 318  recommended
# 319     shortest
#
# [320 rows x 5 columns]

# %% [markdown]
# ## Length and solar exposure distribution

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
palette = sns.color_palette("Set2", 2)

p = sns.catplot(
    kind='box',
    data=df_merged,
    x='route_type',
    y='s_exp',
    hue='route_type',
    legend=False,
    col='time_day',
    col_wrap=4,
    height=6,
    aspect=0.8,
    palette=palette,
    col_order=['morning', 'noon', 'afternoon', 'evening']
)


p.set_titles("{col_name}")
p.set_axis_labels("", "Solar Exposure [%]")
p.despine(left=True)
p.fig.subplots_adjust(top=0.9)
p.fig.suptitle("Solar Exposure Distribution by Route Type and Time of Day", fontsize=10, fontweight='bold')


p.fig.text(0.5, 0.02, "Route type", ha='center', fontsize=12)

p.savefig("s_exp_route_type_timeofday.png", dpi=400, bbox_inches='tight')

plt.show()

# %%
palette = sns.color_palette("Set2", 2)

p = sns.catplot(
    kind='box',
    data=df_merged,
    x='route_type',
    y='distance',
    hue='route_type',
    legend=False,
    col='time_day',
    col_wrap=4,
    height=6,
    aspect=0.8,
    palette=palette,
    col_order=['morning', 'noon', 'afternoon', 'evening']
)


p.set_titles("{col_name}")
p.set_axis_labels("", "Length [m]")
p.despine(left=True)
p.fig.subplots_adjust(top=0.9)
p.fig.suptitle("Length Distribution by Route Type and Time of Day", fontsize=10, fontweight='bold')


p.fig.text(0.5, 0.02, "Route type", ha='center', fontsize=12)

p.savefig("length_route_type_timeofday.png", dpi=400, bbox_inches='tight')

plt.show()

# %%
df_merged['source_no_route'] = df_merged['source'].str.rsplit('_', n=1).str[0]
df_merged
# Out:
#                             source  distance      s_exp   time_day  \
# 0    route_0_afternoon_recommended    9428.4  42.863169  afternoon
# 1       route_0_afternoon_shortest    8968.3  43.237247  afternoon
# 2      route_0_evening_recommended    9509.0  31.369408    evening
# 3         route_0_evening_shortest    9004.7  34.267982    evening
# 4      route_0_morning_recommended    9355.5  37.661867    morning
# ..                             ...       ...        ...        ...
# 315       route_9_evening_shortest    7490.4  17.154037    evening
# 316    route_9_morning_recommended    8576.0   9.043925    morning
# 317       route_9_morning_shortest    8506.3   8.894114    morning
# 318       route_9_noon_recommended    7553.3  28.051924       noon
# 319          route_9_noon_shortest    7490.4  28.287488       noon
#
#       route_type    source_no_route
# 0    recommended  route_0_afternoon
# 1       shortest  route_0_afternoon
# 2    recommended    route_0_evening
# 3       shortest    route_0_evening
# 4    recommended    route_0_morning
# ..           ...                ...
# 315     shortest    route_9_evening
# 316  recommended    route_9_morning
# 317     shortest    route_9_morning
# 318  recommended       route_9_noon
# 319     shortest       route_9_noon
#
# [320 rows x 6 columns]

# %%
wide_df = df_merged.pivot(
    index='source_no_route',
    columns='route_type',
    values='distance'
)

# %%
wide_df['Score_diff'] = wide_df['recommended'] - wide_df['shortest']
wide_df
# Out:
# route_type          recommended  shortest  Score_diff
# source_no_route
# route_0_afternoon        9428.4    8968.3       460.1
# route_0_evening          9509.0    9004.7       504.3
# route_0_morning          9355.5    9115.5       240.0
# route_0_noon             9028.7    8976.0        52.7
# route_10_afternoon       4008.2    4016.0        -7.8
# ...                         ...       ...         ...
# route_8_noon             6581.1    6573.3         7.8
# route_9_afternoon        7553.3    7490.4        62.9
# route_9_evening          7603.3    7490.4       112.9
# route_9_morning          8576.0    8506.3        69.7
# route_9_noon             7553.3    7490.4        62.9
#
# [160 rows x 3 columns]

# %%
big_diff = (wide_df['recommended'] - wide_df['shortest']).abs().idxmax()
big_diff
# Out:
# 'route_16_morning'

# %%
gdf1 = gpd.read_file(f'../data/run_v1/01_raw/01_routes/{big_diff}_recommended.geojson')
gdf2= gpd.read_file(f'../data/run_v1/01_raw/01_routes/{big_diff}_shortest.geojson')

df1 = df_merged[df_merged['source'] == f'{big_diff}_recommended']
df2 = df_merged[df_merged['source'] == f'{big_diff}_shortest']

gdf1['solar_exp'] = df1.iloc[0]['s_exp']
gdf1['source'] = df1.iloc[0]['source']
gdf2['solar_exp'] = df2.iloc[0]['s_exp']
gdf2['source'] = df2.iloc[0]['source']


gdf_combined = pd.concat([gdf1, gdf2], ignore_index=True)

gdf_combined
# Out:
# Skipping field way_points: unsupported OGR type: 1
# Skipping field way_points: unsupported OGR type: 1
#    ascent  descent                                             extras  \
# 0   632.5    508.0  { "csv": { "values": [ [ 0, 7, 100 ], [ 7, 12,...
# 1   690.5    566.0  { "csv": { "values": [ [ 0, 7, 100 ], [ 7, 12,...
#
#                                              summary  \
# 0  { "distance": 9677.0, "duration": 6967.3999999...
# 1  { "distance": 8062.0, "duration": 5804.6000000...
#
#                                             geometry  solar_exp  \
# 0  LINESTRING Z (8.75573 49.43018 320, 8.75533 49...  39.405318
# 1  LINESTRING Z (8.75573 49.43018 320, 8.75533 49...  61.028392
#
#                          source
# 0  route_16_morning_recommended
# 1     route_16_morning_shortest

# %%
gdf_combined['source'].unique()
# Out:
# array(['route_16_morning_recommended', 'route_16_morning_shortest'],
#       dtype=object)

# %%
import folium
import branca

m = folium.Map([49.4, 8.7], zoom_start=10, tiles='cartodbpositron')

min_val = gdf_combined['solar_exp'].min()
max_val = gdf_combined['solar_exp'].max()
colormap = branca.colormap.LinearColormap(
    colors=['blue', 'green', 'yellow', 'red'],
    vmin=min_val,
    vmax=max_val,
    caption='Solar Exposure'
)



for source in gdf_combined['source'].unique():
    fg = folium.FeatureGroup(name=f"Route: {source}")
    
    geojson = folium.GeoJson(
        gdf_combined[gdf_combined['source'] == source],
        style_function=lambda feature, cmap=colormap: {
            'color': cmap(feature['properties']['solar_exp']),
            'weight': 3,
            'opacity': 1
        }
    )
    
    geojson.add_to(fg)
    fg.add_to(m)

folium.LayerControl().add_to(m)

colormap.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c871e357fc5ad160b997bf886889409 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c871e357fc5ad160b997bf886889409&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c871e357fc5ad160b997bf886889409 = L.map(
#                 &quot;map_7c871e357fc5ad160b997bf886889409&quot;,
#                 {
#                     center: [49.4, 8.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df98126a7ad4006033c9a28d8e494853 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_
# %% [markdown]
# ## Solar exposure

# %%
wide_df = df_merged.pivot(
    index='source_no_route',
    columns='route_type',
    values='s_exp'
)

# %%
big_diff = (wide_df['recommended'] - wide_df['shortest']).abs().idxmax()
big_diff
# Out:
# 'route_11_morning'

# %%
gdf1 = gpd.read_file(f'../data/run_v1/01_raw/01_routes/{big_diff}_recommended.geojson')
gdf2= gpd.read_file(f'../data/run_v1/01_raw/01_routes/{big_diff}_shortest.geojson')

df1 = df_merged[df_merged['source'] == f'{big_diff}_recommended']
df2 = df_merged[df_merged['source'] == f'{big_diff}_shortest']

gdf1['solar_exp'] = df1.iloc[0]['s_exp']
gdf1['source'] = df1.iloc[0]['source']
gdf2['solar_exp'] = df2.iloc[0]['s_exp']
gdf2['source'] = df2.iloc[0]['source']


gdf_combined = pd.concat([gdf1, gdf2], ignore_index=True)

gdf_combined
# Out:
# Skipping field way_points: unsupported OGR type: 1
# Skipping field way_points: unsupported OGR type: 1
#    ascent  descent                                             extras  \
# 0   632.5    508.0  { "csv": { "values": [ [ 0, 7, 100 ], [ 7, 12,...
# 1   690.5    566.0  { "csv": { "values": [ [ 0, 7, 100 ], [ 7, 12,...
#
#                                              summary  \
# 0  { "distance": 9677.0, "duration": 6967.3999999...
# 1  { "distance": 8062.0, "duration": 5804.6000000...
#
#                                             geometry  solar_exp  \
# 0  LINESTRING Z (8.75573 49.43018 320, 8.75533 49...  39.405318
# 1  LINESTRING Z (8.75573 49.43018 320, 8.75533 49...  61.028392
#
#                          source
# 0  route_16_morning_recommended
# 1     route_16_morning_shortest

# %%
import folium
import branca

m = folium.Map([49.4, 8.7], zoom_start=12, tiles='cartodbpositron')

min_val = gdf_combined['solar_exp'].min()
max_val = gdf_combined['solar_exp'].max()
colormap = branca.colormap.LinearColormap(
    colors=['blue', 'green', 'yellow', 'red'],
    vmin=min_val,
    vmax=max_val,
    caption='Solar Exposure'
)



for source in gdf_combined['source'].unique():
    fg = folium.FeatureGroup(name=f"Route: {source}")

    geojson = folium.GeoJson(
        gdf_combined[gdf_combined['source'] == source],
        style_function=lambda feature, cmap=colormap: {
            'color': cmap(feature['properties']['solar_exp']),
            'weight': 3,
            'opacity': 1
        }
    )

    geojson.add_to(fg)
    fg.add_to(m)

folium.LayerControl().add_to(m)

colormap.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf0a9868ef0c9280225ce6b02d6f0422 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf0a9868ef0c9280225ce6b02d6f0422&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf0a9868ef0c9280225ce6b02d6f0422 = L.map(
#                 &quot;map_bf0a9868ef0c9280225ce6b02d6f0422&quot;,
#                 {
#                     center: [49.4, 8.7],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac58937968429517c0e76a2485ecd68b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ac58937968429517c0e76a2485ecd68b.addTo(map_bf0a9868ef0c9280225ce6b02d6f0422);
#
#
#             var feature_group_648439eb64f5148cebe36f3257d01ab0 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_ec7a55ef7d49735c3362a495771faebf_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0000ffff&quot;, &quot;opacity&quot;: 1, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_ec7a55ef7d49735c3362a495771faebf_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_